# %%
import requests

# %%
# Function to process wanted data from unwanted data
def process_data(raw_incidents):
  return [{
      'name': incident['displayname'],
      'birthplace': incident['birthplace'],
      'culture': incident['culture']
      } for incident in raw_incidents]  # Repeating process per each 'record'

# %%
API_KEY = '240f4c10-0c0a-11ea-9686-4fc85a8e28c2'  # API Key retrieved from Harvard
BASE_URL = 'https://api.harvardartmuseums.org'
MAX_RETRIES = 10  # Set max number of retries for bad responses

# Declare paramaters to fill in request
resource = '/person'
q = 'culture:British'
apikey = '?apikey=' + API_KEY

# initialize incidents
incidents = []

# set paging to move through results
size = 100
page = 45

# Set the url and query to make request
url = BASE_URL + resource + apikey
query = {'page': page, 'size': size, 'q': q}

# recieve response from request
response = requests.get(url, params=query)
print('making request to {}'.format(url))
print(response.ok)

# make sure request is valid
if response.ok:
  data = response.json()      # Move data to dictionary

  response_info = data['info']  # Look at info to get a few response details
  total_records = response_info['totalrecords']
  total_pages = response_info['pages']

  print('{} results to process'.format(total_records))

  incidents = process_data(data['records']) # process first page of data

  # Set next page up
  page += 1
  retries = 0

  # Repeat the process until last page
  while page <= total_pages and retries < MAX_RETRIES:
    query = {'page': page, 'size': size, 'q': q}
    
    response = requests.get(url, params=query)

    if response.ok:
      incidents = incidents + process_data(data['records'])
      page += 1
    else: # If the response is bad, try again up to MAX_RETRIES times to get a good response, or abort
      retries += 1
      print('bad response, retrying {}'.format(retries))

incidents
# Out:
# making request to https://api.harvardartmuseums.org/person?apikey=240f4c10-0c0a-11ea-9686-4fc85a8e28c2
# True
# 1862 results to process
# [{'birthplace': 'Buntingford, Hertfordshire, UK',
#   'culture': 'British',
#   'name': 'Reginald Cotterell Butler'},
#  {'birthplace': 'Burton-on-Trent, England',
#   'culture': 'British',
#   'name': 'Helen Allingham'},
#  {'birthplace': None, 'culture': 'British', 'name': 'George Reavey'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Joe Tilson'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Robert Leman'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Richard Morphet'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Walter Moncton Keesey'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Jeavons'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Andreas van Rymsdyck'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Camden Edwards'},
#  {'birthplace': None, 'culture': 'British?', 'name': 'Richard Barrett'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Robert Sayer'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Boxing Series'},
#  {'birthplace': 'London', 'culture': 'British', 'name': 'James Stuart'},
#  {'birthplace': 'Rochford, United Kingdom',
#   'culture': 'British',
#   'name': 'Tris Vonna-Michell'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Alfred Rosling'},
#  {'birthplace': 'India', 'culture': 'British', 'name': 'Charles E. Brown'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Pitts I'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Jean Baptiste Michel'},
#  {'birthplace': None, 'culture': 'British', 'name': 'James Redaway'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Henry Simmons'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William James Ward'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Neagle'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Vernon'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Woolnoth'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Scott'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Bradford'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Clarkson Stansfield'},
#  {'birthplace': None, 'culture': 'British', 'name': 'George Smith'},
#  {'birthplace': None,
#   'culture': 'British',
#   'name': 'Charles Catton the Younger'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Gainsborough Dupont'},
#  {'birthplace': None, 'culture': 'British', 'name': 'James Crespell'},
#  {'birthplace': 'London, England',
#   'culture': 'British',
#   'name': 'Cecil Beaton'},
#  {'birthplace': 'England',
#   'culture': 'British',
#   'name': 'Clare Veronica Hope Leighton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Richard Bankes Harraden'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Peter Hollins'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Margaret Gillies'},
#  {'birthplace': None, 'culture': 'British', 'name': 'James Godsell Middleton'},
#  {'birthplace': 'Plymouth, England',
#   'culture': 'British',
#   'name': 'James Northcote'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Joseph Durham'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Bartholomew Dandridge'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Hassell'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Artaud'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Inigo Richards'},
#  {'birthplace': None, 'culture': 'British', 'name': "Maker's mark BT"},
#  {'birthplace': None, 'culture': 'British', 'name': 'Charles Borckhardt'},
#  {'birthplace': 'London',
#   'culture': 'British',
#   'name': 'John Augustus Atkinson'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Emerson Crawhall'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Michael Sandle'},
#  {'birthplace': None, 'culture': 'British', 'name': 'M & N Hanhart'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Miss Rolle'},
#  {'birthplace': 'London',
#   'culture': 'British',
#   'name': 'Charles Joseph Hullmandel'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Samuel Read'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Jean François Hue'},
#  {'birthplace': None,
#   'culture': 'British',
#   'name': 'Valentine Cameron Prinsep'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Henry Park'},
#  {'birthplace': None, 'culture': 'British', 'name': 'H. Garret'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Philip Crocker'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Alexander'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Arthur Osborne'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Robert Walker'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Walmsley'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Samuel Collings'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Edward Alfred Goodall'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Edward Penny'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Le Blond & Co.'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Elizabeth Dacheray'},
#  {'birthplace': None, 'culture': 'British', 'name': 'George Humphrey'},
#  {'birthplace': None, 'culture': 'British', 'name': 'George Bullock'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Charles Cotton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Hosmer Shepherd'},
#  {'birthplace': None,
#   'culture': 'British',
#   'name': 'François Alexandre Pernot'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Leighton Leitch'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Ann Bateman'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Joshua Kirby'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Solomon Cole'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Elkington & Co.'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Rock & Co.'},
#  {'birthplace': None, 'culture': 'British?', 'name': 'J. Eames'},
#  {'birthplace': 'London',
#   'culture': 'British',
#   'name': 'George Seddon, Sons, & Shackleton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Robert Bright Marston'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Window & Bridge'},
#  {'birthplace': None, 'culture': 'British', 'name': 'A & E Seeley'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Anne Susan Zileri'},
#  {'birthplace': 'London, England',
#   'culture': 'British',
#   'name': 'Willoughby Wallace Hooper'},
#  {'birthplace': 'Scarborough England',
#   'culture': 'British',
#   'name': 'Frederic Leighton'},
#  {'birthplace': 'Plymouth, England',
#   'culture': 'British',
#   'name': 'William Payne'},
#  {'birthplace': 'York, England',
#   'culture': 'British',
#   'name': 'Albert Joseph Moore'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Patrick Caulfield'},
#  {'birthplace': None, 'culture': 'British', 'name': 'L. Caldesi'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Fradelle & Marshall'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Cornelius Bland'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Chapman & Co.'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Samuel Welder'},
#  {'birthplace': 'Dudley, England',
#   'culture': 'British',
#   'name': 'Thomas Phillips'},
#  {'birthplace': None, 'culture': 'British', 'name': 'J. Paton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'W. P. Barrett'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Richard Dalton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Butterworth and Heath'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Edward Francis Finden'},
#  {'birthplace': 'Buntingford, Hertfordshire, UK',
#   'culture': 'British',
#   'name': 'Reginald Cotterell Butler'},
#  {'birthplace': 'Burton-on-Trent, England',
#   'culture': 'British',
#   'name': 'Helen Allingham'},
#  {'birthplace': None, 'culture': 'British', 'name': 'George Reavey'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Joe Tilson'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Robert Leman'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Richard Morphet'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Walter Moncton Keesey'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Jeavons'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Andreas van Rymsdyck'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Camden Edwards'},
#  {'birthplace': None, 'culture': 'British?', 'name': 'Richard Barrett'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Robert Sayer'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Boxing Series'},
#  {'birthplace': 'London', 'culture': 'British', 'name': 'James Stuart'},
#  {'birthplace': 'Rochford, United Kingdom',
#   'culture': 'British',
#   'name': 'Tris Vonna-Michell'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Alfred Rosling'},
#  {'birthplace': 'India', 'culture': 'British', 'name': 'Charles E. Brown'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Pitts I'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Jean Baptiste Michel'},
#  {'birthplace': None, 'culture': 'British', 'name': 'James Redaway'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Henry Simmons'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William James Ward'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Neagle'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Vernon'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Woolnoth'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Scott'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Bradford'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Clarkson Stansfield'},
#  {'birthplace': None, 'culture': 'British', 'name': 'George Smith'},
#  {'birthplace': None,
#   'culture': 'British',
#   'name': 'Charles Catton the Younger'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Gainsborough Dupont'},
#  {'birthplace': None, 'culture': 'British', 'name': 'James Crespell'},
#  {'birthplace': 'London, England',
#   'culture': 'British',
#   'name': 'Cecil Beaton'},
#  {'birthplace': 'England',
#   'culture': 'British',
#   'name': 'Clare Veronica Hope Leighton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Richard Bankes Harraden'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Peter Hollins'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Margaret Gillies'},
#  {'birthplace': None, 'culture': 'British', 'name': 'James Godsell Middleton'},
#  {'birthplace': 'Plymouth, England',
#   'culture': 'British',
#   'name': 'James Northcote'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Joseph Durham'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Bartholomew Dandridge'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Hassell'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Artaud'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Inigo Richards'},
#  {'birthplace': None, 'culture': 'British', 'name': "Maker's mark BT"},
#  {'birthplace': None, 'culture': 'British', 'name': 'Charles Borckhardt'},
#  {'birthplace': 'London',
#   'culture': 'British',
#   'name': 'John Augustus Atkinson'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Emerson Crawhall'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Michael Sandle'},
#  {'birthplace': None, 'culture': 'British', 'name': 'M & N Hanhart'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Miss Rolle'},
#  {'birthplace': 'London',
#   'culture': 'British',
#   'name': 'Charles Joseph Hullmandel'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Samuel Read'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Jean François Hue'},
#  {'birthplace': None,
#   'culture': 'British',
#   'name': 'Valentine Cameron Prinsep'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Henry Park'},
#  {'birthplace': None, 'culture': 'British', 'name': 'H. Garret'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Philip Crocker'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Alexander'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Arthur Osborne'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Robert Walker'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Walmsley'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Samuel Collings'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Edward Alfred Goodall'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Edward Penny'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Le Blond & Co.'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Elizabeth Dacheray'},
#  {'birthplace': None, 'culture': 'British', 'name': 'George Humphrey'},
#  {'birthplace': None, 'culture': 'British', 'name': 'George Bullock'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Charles Cotton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Hosmer Shepherd'},
#  {'birthplace': None,
#   'culture': 'British',
#   'name': 'François Alexandre Pernot'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Leighton Leitch'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Ann Bateman'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Joshua Kirby'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Solomon Cole'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Elkington & Co.'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Rock & Co.'},
#  {'birthplace': None, 'culture': 'British?', 'name': 'J. Eames'},
#  {'birthplace': 'London',
#   'culture': 'British',
#   'name': 'George Seddon, Sons, & Shackleton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Robert Bright Marston'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Window & Bridge'},
#  {'birthplace': None, 'culture': 'British', 'name': 'A & E Seeley'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Anne Susan Zileri'},
#  {'birthplace': 'London, England',
#   'culture': 'British',
#   'name': 'Willoughby Wallace Hooper'},
#  {'birthplace': 'Scarborough England',
#   'culture': 'British',
#   'name': 'Frederic Leighton'},
#  {'birthplace': 'Plymouth, England',
#   'culture': 'British',
#   'name': 'William Payne'},
#  {'birthplace': 'York, England',
#   'culture': 'British',
#   'name': 'Albert Joseph Moore'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Patrick Caulfield'},
#  {'birthplace': None, 'culture': 'British', 'name': 'L. Caldesi'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Fradelle & Marshall'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Cornelius Bland'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Chapman & Co.'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Samuel Welder'},
#  {'birthplace': 'Dudley, England',
#   'culture': 'British',
#   'name': 'Thomas Phillips'},
#  {'birthplace': None, 'culture': 'British', 'name': 'J. Paton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'W. P. Barrett'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Richard Dalton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Butterworth and Heath'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Edward Francis Finden'},
#  {'birthplace': 'Buntingford, Hertfordshire, UK',
#   'culture': 'British',
#   'name': 'Reginald Cotterell Butler'},
#  {'birthplace': 'Burton-on-Trent, England',
#   'culture': 'British',
#   'name': 'Helen Allingham'},
#  {'birthplace': None, 'culture': 'British', 'name': 'George Reavey'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Joe Tilson'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Robert Leman'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Richard Morphet'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Walter Moncton Keesey'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Jeavons'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Andreas van Rymsdyck'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Camden Edwards'},
#  {'birthplace': None, 'culture': 'British?', 'name': 'Richard Barrett'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Robert Sayer'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Boxing Series'},
#  {'birthplace': 'London', 'culture': 'British', 'name': 'James Stuart'},
#  {'birthplace': 'Rochford, United Kingdom',
#   'culture': 'British',
#   'name': 'Tris Vonna-Michell'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Alfred Rosling'},
#  {'birthplace': 'India', 'culture': 'British', 'name': 'Charles E. Brown'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Pitts I'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Jean Baptiste Michel'},
#  {'birthplace': None, 'culture': 'British', 'name': 'James Redaway'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Henry Simmons'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William James Ward'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Neagle'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Vernon'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Woolnoth'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Scott'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Bradford'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Clarkson Stansfield'},
#  {'birthplace': None, 'culture': 'British', 'name': 'George Smith'},
#  {'birthplace': None,
#   'culture': 'British',
#   'name': 'Charles Catton the Younger'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Gainsborough Dupont'},
#  {'birthplace': None, 'culture': 'British', 'name': 'James Crespell'},
#  {'birthplace': 'London, England',
#   'culture': 'British',
#   'name': 'Cecil Beaton'},
#  {'birthplace': 'England',
#   'culture': 'British',
#   'name': 'Clare Veronica Hope Leighton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Richard Bankes Harraden'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Peter Hollins'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Margaret Gillies'},
#  {'birthplace': None, 'culture': 'British', 'name': 'James Godsell Middleton'},
#  {'birthplace': 'Plymouth, England',
#   'culture': 'British',
#   'name': 'James Northcote'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Joseph Durham'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Bartholomew Dandridge'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Hassell'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Artaud'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Inigo Richards'},
#  {'birthplace': None, 'culture': 'British', 'name': "Maker's mark BT"},
#  {'birthplace': None, 'culture': 'British', 'name': 'Charles Borckhardt'},
#  {'birthplace': 'London',
#   'culture': 'British',
#   'name': 'John Augustus Atkinson'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Emerson Crawhall'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Michael Sandle'},
#  {'birthplace': None, 'culture': 'British', 'name': 'M & N Hanhart'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Miss Rolle'},
#  {'birthplace': 'London',
#   'culture': 'British',
#   'name': 'Charles Joseph Hullmandel'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Samuel Read'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Jean François Hue'},
#  {'birthplace': None,
#   'culture': 'British',
#   'name': 'Valentine Cameron Prinsep'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Henry Park'},
#  {'birthplace': None, 'culture': 'British', 'name': 'H. Garret'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Philip Crocker'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Alexander'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Arthur Osborne'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Robert Walker'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Walmsley'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Samuel Collings'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Edward Alfred Goodall'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Edward Penny'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Le Blond & Co.'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Elizabeth Dacheray'},
#  {'birthplace': None, 'culture': 'British', 'name': 'George Humphrey'},
#  {'birthplace': None, 'culture': 'British', 'name': 'George Bullock'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Charles Cotton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Hosmer Shepherd'},
#  {'birthplace': None,
#   'culture': 'British',
#   'name': 'François Alexandre Pernot'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Leighton Leitch'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Ann Bateman'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Joshua Kirby'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Solomon Cole'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Elkington & Co.'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Rock & Co.'},
#  {'birthplace': None, 'culture': 'British?', 'name': 'J. Eames'},
#  {'birthplace': 'London',
#   'culture': 'British',
#   'name': 'George Seddon, Sons, & Shackleton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Robert Bright Marston'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Window & Bridge'},
#  {'birthplace': None, 'culture': 'British', 'name': 'A & E Seeley'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Anne Susan Zileri'},
#  {'birthplace': 'London, England',
#   'culture': 'British',
#   'name': 'Willoughby Wallace Hooper'},
#  {'birthplace': 'Scarborough England',
#   'culture': 'British',
#   'name': 'Frederic Leighton'},
#  {'birthplace': 'Plymouth, England',
#   'culture': 'British',
#   'name': 'William Payne'},
#  {'birthplace': 'York, England',
#   'culture': 'British',
#   'name': 'Albert Joseph Moore'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Patrick Caulfield'},
#  {'birthplace': None, 'culture': 'British', 'name': 'L. Caldesi'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Fradelle & Marshall'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Cornelius Bland'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Chapman & Co.'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Samuel Welder'},
#  {'birthplace': 'Dudley, England',
#   'culture': 'British',
#   'name': 'Thomas Phillips'},
#  {'birthplace': None, 'culture': 'British', 'name': 'J. Paton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'W. P. Barrett'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Richard Dalton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Butterworth and Heath'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Edward Francis Finden'},
#  {'birthplace': 'Buntingford, Hertfordshire, UK',
#   'culture': 'British',
#   'name': 'Reginald Cotterell Butler'},
#  {'birthplace': 'Burton-on-Trent, England',
#   'culture': 'British',
#   'name': 'Helen Allingham'},
#  {'birthplace': None, 'culture': 'British', 'name': 'George Reavey'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Joe Tilson'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Robert Leman'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Richard Morphet'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Walter Moncton Keesey'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Jeavons'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Andreas van Rymsdyck'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Camden Edwards'},
#  {'birthplace': None, 'culture': 'British?', 'name': 'Richard Barrett'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Robert Sayer'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Boxing Series'},
#  {'birthplace': 'London', 'culture': 'British', 'name': 'James Stuart'},
#  {'birthplace': 'Rochford, United Kingdom',
#   'culture': 'British',
#   'name': 'Tris Vonna-Michell'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Alfred Rosling'},
#  {'birthplace': 'India', 'culture': 'British', 'name': 'Charles E. Brown'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Pitts I'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Jean Baptiste Michel'},
#  {'birthplace': None, 'culture': 'British', 'name': 'James Redaway'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Henry Simmons'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William James Ward'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Neagle'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Vernon'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Woolnoth'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Scott'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Bradford'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Clarkson Stansfield'},
#  {'birthplace': None, 'culture': 'British', 'name': 'George Smith'},
#  {'birthplace': None,
#   'culture': 'British',
#   'name': 'Charles Catton the Younger'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Gainsborough Dupont'},
#  {'birthplace': None, 'culture': 'British', 'name': 'James Crespell'},
#  {'birthplace': 'London, England',
#   'culture': 'British',
#   'name': 'Cecil Beaton'},
#  {'birthplace': 'England',
#   'culture': 'British',
#   'name': 'Clare Veronica Hope Leighton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Richard Bankes Harraden'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Peter Hollins'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Margaret Gillies'},
#  {'birthplace': None, 'culture': 'British', 'name': 'James Godsell Middleton'},
#  {'birthplace': 'Plymouth, England',
#   'culture': 'British',
#   'name': 'James Northcote'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Joseph Durham'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Bartholomew Dandridge'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Hassell'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Artaud'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Inigo Richards'},
#  {'birthplace': None, 'culture': 'British', 'name': "Maker's mark BT"},
#  {'birthplace': None, 'culture': 'British', 'name': 'Charles Borckhardt'},
#  {'birthplace': 'London',
#   'culture': 'British',
#   'name': 'John Augustus Atkinson'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Emerson Crawhall'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Michael Sandle'},
#  {'birthplace': None, 'culture': 'British', 'name': 'M & N Hanhart'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Miss Rolle'},
#  {'birthplace': 'London',
#   'culture': 'British',
#   'name': 'Charles Joseph Hullmandel'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Samuel Read'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Jean François Hue'},
#  {'birthplace': None,
#   'culture': 'British',
#   'name': 'Valentine Cameron Prinsep'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Henry Park'},
#  {'birthplace': None, 'culture': 'British', 'name': 'H. Garret'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Philip Crocker'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Alexander'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Arthur Osborne'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Robert Walker'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Walmsley'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Samuel Collings'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Edward Alfred Goodall'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Edward Penny'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Le Blond & Co.'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Elizabeth Dacheray'},
#  {'birthplace': None, 'culture': 'British', 'name': 'George Humphrey'},
#  {'birthplace': None, 'culture': 'British', 'name': 'George Bullock'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Charles Cotton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Hosmer Shepherd'},
#  {'birthplace': None,
#   'culture': 'British',
#   'name': 'François Alexandre Pernot'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Leighton Leitch'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Ann Bateman'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Joshua Kirby'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Solomon Cole'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Elkington & Co.'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Rock & Co.'},
#  {'birthplace': None, 'culture': 'British?', 'name': 'J. Eames'},
#  {'birthplace': 'London',
#   'culture': 'British',
#   'name': 'George Seddon, Sons, & Shackleton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Robert Bright Marston'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Window & Bridge'},
#  {'birthplace': None, 'culture': 'British', 'name': 'A & E Seeley'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Anne Susan Zileri'},
#  {'birthplace': 'London, England',
#   'culture': 'British',
#   'name': 'Willoughby Wallace Hooper'},
#  {'birthplace': 'Scarborough England',
#   'culture': 'British',
#   'name': 'Frederic Leighton'},
#  {'birthplace': 'Plymouth, England',
#   'culture': 'British',
#   'name': 'William Payne'},
#  {'birthplace': 'York, England',
#   'culture': 'British',
#   'name': 'Albert Joseph Moore'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Patrick Caulfield'},
#  {'birthplace': None, 'culture': 'British', 'name': 'L. Caldesi'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Fradelle & Marshall'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Cornelius Bland'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Chapman & Co.'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Samuel Welder'},
#  {'birthplace': 'Dudley, England',
#   'culture': 'British',
#   'name': 'Thomas Phillips'},
#  {'birthplace': None, 'culture': 'British', 'name': 'J. Paton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'W. P. Barrett'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Richard Dalton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Butterworth and Heath'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Edward Francis Finden'},
#  {'birthplace': 'Buntingford, Hertfordshire, UK',
#   'culture': 'British',
#   'name': 'Reginald Cotterell Butler'},
#  {'birthplace': 'Burton-on-Trent, England',
#   'culture': 'British',
#   'name': 'Helen Allingham'},
#  {'birthplace': None, 'culture': 'British', 'name': 'George Reavey'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Joe Tilson'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Robert Leman'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Richard Morphet'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Walter Moncton Keesey'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Jeavons'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Andreas van Rymsdyck'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Camden Edwards'},
#  {'birthplace': None, 'culture': 'British?', 'name': 'Richard Barrett'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Robert Sayer'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Boxing Series'},
#  {'birthplace': 'London', 'culture': 'British', 'name': 'James Stuart'},
#  {'birthplace': 'Rochford, United Kingdom',
#   'culture': 'British',
#   'name': 'Tris Vonna-Michell'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Alfred Rosling'},
#  {'birthplace': 'India', 'culture': 'British', 'name': 'Charles E. Brown'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Pitts I'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Jean Baptiste Michel'},
#  {'birthplace': None, 'culture': 'British', 'name': 'James Redaway'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Henry Simmons'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William James Ward'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Neagle'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Vernon'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Woolnoth'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Scott'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Bradford'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Clarkson Stansfield'},
#  {'birthplace': None, 'culture': 'British', 'name': 'George Smith'},
#  {'birthplace': None,
#   'culture': 'British',
#   'name': 'Charles Catton the Younger'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Gainsborough Dupont'},
#  {'birthplace': None, 'culture': 'British', 'name': 'James Crespell'},
#  {'birthplace': 'London, England',
#   'culture': 'British',
#   'name': 'Cecil Beaton'},
#  {'birthplace': 'England',
#   'culture': 'British',
#   'name': 'Clare Veronica Hope Leighton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Richard Bankes Harraden'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Peter Hollins'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Margaret Gillies'},
#  {'birthplace': None, 'culture': 'British', 'name': 'James Godsell Middleton'},
#  {'birthplace': 'Plymouth, England',
#   'culture': 'British',
#   'name': 'James Northcote'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Joseph Durham'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Bartholomew Dandridge'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Hassell'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Artaud'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Inigo Richards'},
#  {'birthplace': None, 'culture': 'British', 'name': "Maker's mark BT"},
#  {'birthplace': None, 'culture': 'British', 'name': 'Charles Borckhardt'},
#  {'birthplace': 'London',
#   'culture': 'British',
#   'name': 'John Augustus Atkinson'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Emerson Crawhall'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Michael Sandle'},
#  {'birthplace': None, 'culture': 'British', 'name': 'M & N Hanhart'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Miss Rolle'},
#  {'birthplace': 'London',
#   'culture': 'British',
#   'name': 'Charles Joseph Hullmandel'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Samuel Read'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Jean François Hue'},
#  {'birthplace': None,
#   'culture': 'British',
#   'name': 'Valentine Cameron Prinsep'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Henry Park'},
#  {'birthplace': None, 'culture': 'British', 'name': 'H. Garret'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Philip Crocker'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Alexander'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Arthur Osborne'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Robert Walker'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Walmsley'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Samuel Collings'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Edward Alfred Goodall'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Edward Penny'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Le Blond & Co.'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Elizabeth Dacheray'},
#  {'birthplace': None, 'culture': 'British', 'name': 'George Humphrey'},
#  {'birthplace': None, 'culture': 'British', 'name': 'George Bullock'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Charles Cotton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Hosmer Shepherd'},
#  {'birthplace': None,
#   'culture': 'British',
#   'name': 'François Alexandre Pernot'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Leighton Leitch'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Ann Bateman'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Joshua Kirby'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Solomon Cole'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Elkington & Co.'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Rock & Co.'},
#  {'birthplace': None, 'culture': 'British?', 'name': 'J. Eames'},
#  {'birthplace': 'London',
#   'culture': 'British',
#   'name': 'George Seddon, Sons, & Shackleton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Robert Bright Marston'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Window & Bridge'},
#  {'birthplace': None, 'culture': 'British', 'name': 'A & E Seeley'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Anne Susan Zileri'},
#  {'birthplace': 'London, England',
#   'culture': 'British',
#   'name': 'Willoughby Wallace Hooper'},
#  {'birthplace': 'Scarborough England',
#   'culture': 'British',
#   'name': 'Frederic Leighton'},
#  {'birthplace': 'Plymouth, England',
#   'culture': 'British',
#   'name': 'William Payne'},
#  {'birthplace': 'York, England',
#   'culture': 'British',
#   'name': 'Albert Joseph Moore'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Patrick Caulfield'},
#  {'birthplace': None, 'culture': 'British', 'name': 'L. Caldesi'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Fradelle & Marshall'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Cornelius Bland'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Chapman & Co.'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Samuel Welder'},
#  {'birthplace': 'Dudley, England',
#   'culture': 'British',
#   'name': 'Thomas Phillips'},
#  {'birthplace': None, 'culture': 'British', 'name': 'J. Paton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'W. P. Barrett'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Richard Dalton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Butterworth and Heath'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Edward Francis Finden'},
#  {'birthplace': 'Buntingford, Hertfordshire, UK',
#   'culture': 'British',
#   'name': 'Reginald Cotterell Butler'},
#  {'birthplace': 'Burton-on-Trent, England',
#   'culture': 'British',
#   'name': 'Helen Allingham'},
#  {'birthplace': None, 'culture': 'British', 'name': 'George Reavey'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Joe Tilson'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Robert Leman'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Richard Morphet'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Walter Moncton Keesey'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Jeavons'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Andreas van Rymsdyck'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Camden Edwards'},
#  {'birthplace': None, 'culture': 'British?', 'name': 'Richard Barrett'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Robert Sayer'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Boxing Series'},
#  {'birthplace': 'London', 'culture': 'British', 'name': 'James Stuart'},
#  {'birthplace': 'Rochford, United Kingdom',
#   'culture': 'British',
#   'name': 'Tris Vonna-Michell'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Alfred Rosling'},
#  {'birthplace': 'India', 'culture': 'British', 'name': 'Charles E. Brown'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Pitts I'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Jean Baptiste Michel'},
#  {'birthplace': None, 'culture': 'British', 'name': 'James Redaway'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Henry Simmons'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William James Ward'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Neagle'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Vernon'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Woolnoth'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Scott'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Bradford'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Clarkson Stansfield'},
#  {'birthplace': None, 'culture': 'British', 'name': 'George Smith'},
#  {'birthplace': None,
#   'culture': 'British',
#   'name': 'Charles Catton the Younger'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Gainsborough Dupont'},
#  {'birthplace': None, 'culture': 'British', 'name': 'James Crespell'},
#  {'birthplace': 'London, England',
#   'culture': 'British',
#   'name': 'Cecil Beaton'},
#  {'birthplace': 'England',
#   'culture': 'British',
#   'name': 'Clare Veronica Hope Leighton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Richard Bankes Harraden'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Peter Hollins'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Margaret Gillies'},
#  {'birthplace': None, 'culture': 'British', 'name': 'James Godsell Middleton'},
#  {'birthplace': 'Plymouth, England',
#   'culture': 'British',
#   'name': 'James Northcote'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Joseph Durham'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Bartholomew Dandridge'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Hassell'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Artaud'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Inigo Richards'},
#  {'birthplace': None, 'culture': 'British', 'name': "Maker's mark BT"},
#  {'birthplace': None, 'culture': 'British', 'name': 'Charles Borckhardt'},
#  {'birthplace': 'London',
#   'culture': 'British',
#   'name': 'John Augustus Atkinson'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Emerson Crawhall'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Michael Sandle'},
#  {'birthplace': None, 'culture': 'British', 'name': 'M & N Hanhart'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Miss Rolle'},
#  {'birthplace': 'London',
#   'culture': 'British',
#   'name': 'Charles Joseph Hullmandel'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Samuel Read'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Jean François Hue'},
#  {'birthplace': None,
#   'culture': 'British',
#   'name': 'Valentine Cameron Prinsep'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Henry Park'},
#  {'birthplace': None, 'culture': 'British', 'name': 'H. Garret'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Philip Crocker'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Alexander'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Arthur Osborne'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Robert Walker'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Walmsley'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Samuel Collings'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Edward Alfred Goodall'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Edward Penny'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Le Blond & Co.'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Elizabeth Dacheray'},
#  {'birthplace': None, 'culture': 'British', 'name': 'George Humphrey'},
#  {'birthplace': None, 'culture': 'British', 'name': 'George Bullock'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Charles Cotton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Hosmer Shepherd'},
#  {'birthplace': None,
#   'culture': 'British',
#   'name': 'François Alexandre Pernot'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Leighton Leitch'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Ann Bateman'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Joshua Kirby'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Solomon Cole'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Elkington & Co.'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Rock & Co.'},
#  {'birthplace': None, 'culture': 'British?', 'name': 'J. Eames'},
#  {'birthplace': 'London',
#   'culture': 'British',
#   'name': 'George Seddon, Sons, & Shackleton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Robert Bright Marston'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Window & Bridge'},
#  {'birthplace': None, 'culture': 'British', 'name': 'A & E Seeley'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Anne Susan Zileri'},
#  {'birthplace': 'London, England',
#   'culture': 'British',
#   'name': 'Willoughby Wallace Hooper'},
#  {'birthplace': 'Scarborough England',
#   'culture': 'British',
#   'name': 'Frederic Leighton'},
#  {'birthplace': 'Plymouth, England',
#   'culture': 'British',
#   'name': 'William Payne'},
#  {'birthplace': 'York, England',
#   'culture': 'British',
#   'name': 'Albert Joseph Moore'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Patrick Caulfield'},
#  {'birthplace': None, 'culture': 'British', 'name': 'L. Caldesi'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Fradelle & Marshall'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Cornelius Bland'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Chapman & Co.'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Samuel Welder'},
#  {'birthplace': 'Dudley, England',
#   'culture': 'British',
#   'name': 'Thomas Phillips'},
#  {'birthplace': None, 'culture': 'British', 'name': 'J. Paton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'W. P. Barrett'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Richard Dalton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Butterworth and Heath'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Edward Francis Finden'},
#  {'birthplace': 'Buntingford, Hertfordshire, UK',
#   'culture': 'British',
#   'name': 'Reginald Cotterell Butler'},
#  {'birthplace': 'Burton-on-Trent, England',
#   'culture': 'British',
#   'name': 'Helen Allingham'},
#  {'birthplace': None, 'culture': 'British', 'name': 'George Reavey'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Joe Tilson'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Robert Leman'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Richard Morphet'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Walter Moncton Keesey'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Jeavons'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Andreas van Rymsdyck'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Camden Edwards'},
#  {'birthplace': None, 'culture': 'British?', 'name': 'Richard Barrett'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Robert Sayer'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Boxing Series'},
#  {'birthplace': 'London', 'culture': 'British', 'name': 'James Stuart'},
#  {'birthplace': 'Rochford, United Kingdom',
#   'culture': 'British',
#   'name': 'Tris Vonna-Michell'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Alfred Rosling'},
#  {'birthplace': 'India', 'culture': 'British', 'name': 'Charles E. Brown'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Pitts I'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Jean Baptiste Michel'},
#  {'birthplace': None, 'culture': 'British', 'name': 'James Redaway'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Henry Simmons'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William James Ward'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Neagle'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Vernon'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Woolnoth'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Scott'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Bradford'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Clarkson Stansfield'},
#  {'birthplace': None, 'culture': 'British', 'name': 'George Smith'},
#  {'birthplace': None,
#   'culture': 'British',
#   'name': 'Charles Catton the Younger'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Gainsborough Dupont'},
# ...
#  {'birthplace': None, 'culture': 'British', 'name': 'L. Caldesi'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Fradelle & Marshall'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Cornelius Bland'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Chapman & Co.'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Samuel Welder'},
#  {'birthplace': 'Dudley, England',
#   'culture': 'British',
#   'name': 'Thomas Phillips'},
#  {'birthplace': None, 'culture': 'British', 'name': 'J. Paton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'W. P. Barrett'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Richard Dalton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Butterworth and Heath'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Edward Francis Finden'},
#  {'birthplace': 'Buntingford, Hertfordshire, UK',
#   'culture': 'British',
#   'name': 'Reginald Cotterell Butler'},
#  {'birthplace': 'Burton-on-Trent, England',
#   'culture': 'British',
#   'name': 'Helen Allingham'},
#  {'birthplace': None, 'culture': 'British', 'name': 'George Reavey'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Joe Tilson'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Robert Leman'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Richard Morphet'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Walter Moncton Keesey'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Jeavons'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Andreas van Rymsdyck'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Camden Edwards'},
#  {'birthplace': None, 'culture': 'British?', 'name': 'Richard Barrett'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Robert Sayer'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Boxing Series'},
#  {'birthplace': 'London', 'culture': 'British', 'name': 'James Stuart'},
#  {'birthplace': 'Rochford, United Kingdom',
#   'culture': 'British',
#   'name': 'Tris Vonna-Michell'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Alfred Rosling'},
#  {'birthplace': 'India', 'culture': 'British', 'name': 'Charles E. Brown'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Pitts I'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Jean Baptiste Michel'},
#  {'birthplace': None, 'culture': 'British', 'name': 'James Redaway'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Henry Simmons'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William James Ward'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Neagle'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Vernon'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Woolnoth'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Scott'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Bradford'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Clarkson Stansfield'},
#  {'birthplace': None, 'culture': 'British', 'name': 'George Smith'},
#  {'birthplace': None,
#   'culture': 'British',
#   'name': 'Charles Catton the Younger'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Gainsborough Dupont'},
#  {'birthplace': None, 'culture': 'British', 'name': 'James Crespell'},
#  {'birthplace': 'London, England',
#   'culture': 'British',
#   'name': 'Cecil Beaton'},
#  {'birthplace': 'England',
#   'culture': 'British',
#   'name': 'Clare Veronica Hope Leighton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Richard Bankes Harraden'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Peter Hollins'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Margaret Gillies'},
#  {'birthplace': None, 'culture': 'British', 'name': 'James Godsell Middleton'},
#  {'birthplace': 'Plymouth, England',
#   'culture': 'British',
#   'name': 'James Northcote'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Joseph Durham'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Bartholomew Dandridge'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Hassell'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Artaud'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Inigo Richards'},
#  {'birthplace': None, 'culture': 'British', 'name': "Maker's mark BT"},
#  {'birthplace': None, 'culture': 'British', 'name': 'Charles Borckhardt'},
#  {'birthplace': 'London',
#   'culture': 'British',
#   'name': 'John Augustus Atkinson'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Emerson Crawhall'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Michael Sandle'},
#  {'birthplace': None, 'culture': 'British', 'name': 'M & N Hanhart'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Miss Rolle'},
#  {'birthplace': 'London',
#   'culture': 'British',
#   'name': 'Charles Joseph Hullmandel'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Samuel Read'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Jean François Hue'},
#  {'birthplace': None,
#   'culture': 'British',
#   'name': 'Valentine Cameron Prinsep'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Henry Park'},
#  {'birthplace': None, 'culture': 'British', 'name': 'H. Garret'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Philip Crocker'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Alexander'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Arthur Osborne'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Robert Walker'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Walmsley'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Samuel Collings'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Edward Alfred Goodall'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Edward Penny'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Le Blond & Co.'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Elizabeth Dacheray'},
#  {'birthplace': None, 'culture': 'British', 'name': 'George Humphrey'},
#  {'birthplace': None, 'culture': 'British', 'name': 'George Bullock'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Charles Cotton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Hosmer Shepherd'},
#  {'birthplace': None,
#   'culture': 'British',
#   'name': 'François Alexandre Pernot'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Leighton Leitch'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Ann Bateman'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Joshua Kirby'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Solomon Cole'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Elkington & Co.'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Rock & Co.'},
#  {'birthplace': None, 'culture': 'British?', 'name': 'J. Eames'},
#  {'birthplace': 'London',
#   'culture': 'British',
#   'name': 'George Seddon, Sons, & Shackleton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Robert Bright Marston'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Window & Bridge'},
#  {'birthplace': None, 'culture': 'British', 'name': 'A & E Seeley'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Anne Susan Zileri'},
#  {'birthplace': 'London, England',
#   'culture': 'British',
#   'name': 'Willoughby Wallace Hooper'},
#  {'birthplace': 'Scarborough England',
#   'culture': 'British',
#   'name': 'Frederic Leighton'},
#  {'birthplace': 'Plymouth, England',
#   'culture': 'British',
#   'name': 'William Payne'},
#  {'birthplace': 'York, England',
#   'culture': 'British',
#   'name': 'Albert Joseph Moore'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Patrick Caulfield'},
#  {'birthplace': None, 'culture': 'British', 'name': 'L. Caldesi'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Fradelle & Marshall'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Cornelius Bland'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Chapman & Co.'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Samuel Welder'},
#  {'birthplace': 'Dudley, England',
#   'culture': 'British',
#   'name': 'Thomas Phillips'},
#  {'birthplace': None, 'culture': 'British', 'name': 'J. Paton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'W. P. Barrett'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Richard Dalton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Butterworth and Heath'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Edward Francis Finden'},
#  {'birthplace': 'Buntingford, Hertfordshire, UK',
#   'culture': 'British',
#   'name': 'Reginald Cotterell Butler'},
#  {'birthplace': 'Burton-on-Trent, England',
#   'culture': 'British',
#   'name': 'Helen Allingham'},
#  {'birthplace': None, 'culture': 'British', 'name': 'George Reavey'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Joe Tilson'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Robert Leman'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Richard Morphet'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Walter Moncton Keesey'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Jeavons'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Andreas van Rymsdyck'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Camden Edwards'},
#  {'birthplace': None, 'culture': 'British?', 'name': 'Richard Barrett'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Robert Sayer'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Boxing Series'},
#  {'birthplace': 'London', 'culture': 'British', 'name': 'James Stuart'},
#  {'birthplace': 'Rochford, United Kingdom',
#   'culture': 'British',
#   'name': 'Tris Vonna-Michell'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Alfred Rosling'},
#  {'birthplace': 'India', 'culture': 'British', 'name': 'Charles E. Brown'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Pitts I'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Jean Baptiste Michel'},
#  {'birthplace': None, 'culture': 'British', 'name': 'James Redaway'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Henry Simmons'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William James Ward'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Neagle'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Vernon'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Woolnoth'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Scott'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Bradford'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Clarkson Stansfield'},
#  {'birthplace': None, 'culture': 'British', 'name': 'George Smith'},
#  {'birthplace': None,
#   'culture': 'British',
#   'name': 'Charles Catton the Younger'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Gainsborough Dupont'},
#  {'birthplace': None, 'culture': 'British', 'name': 'James Crespell'},
#  {'birthplace': 'London, England',
#   'culture': 'British',
#   'name': 'Cecil Beaton'},
#  {'birthplace': 'England',
#   'culture': 'British',
#   'name': 'Clare Veronica Hope Leighton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Richard Bankes Harraden'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Peter Hollins'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Margaret Gillies'},
#  {'birthplace': None, 'culture': 'British', 'name': 'James Godsell Middleton'},
#  {'birthplace': 'Plymouth, England',
#   'culture': 'British',
#   'name': 'James Northcote'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Joseph Durham'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Bartholomew Dandridge'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Hassell'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Artaud'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Inigo Richards'},
#  {'birthplace': None, 'culture': 'British', 'name': "Maker's mark BT"},
#  {'birthplace': None, 'culture': 'British', 'name': 'Charles Borckhardt'},
#  {'birthplace': 'London',
#   'culture': 'British',
#   'name': 'John Augustus Atkinson'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Emerson Crawhall'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Michael Sandle'},
#  {'birthplace': None, 'culture': 'British', 'name': 'M & N Hanhart'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Miss Rolle'},
#  {'birthplace': 'London',
#   'culture': 'British',
#   'name': 'Charles Joseph Hullmandel'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Samuel Read'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Jean François Hue'},
#  {'birthplace': None,
#   'culture': 'British',
#   'name': 'Valentine Cameron Prinsep'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Henry Park'},
#  {'birthplace': None, 'culture': 'British', 'name': 'H. Garret'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Philip Crocker'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Alexander'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Arthur Osborne'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Robert Walker'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Walmsley'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Samuel Collings'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Edward Alfred Goodall'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Edward Penny'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Le Blond & Co.'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Elizabeth Dacheray'},
#  {'birthplace': None, 'culture': 'British', 'name': 'George Humphrey'},
#  {'birthplace': None, 'culture': 'British', 'name': 'George Bullock'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Charles Cotton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Thomas Hosmer Shepherd'},
#  {'birthplace': None,
#   'culture': 'British',
#   'name': 'François Alexandre Pernot'},
#  {'birthplace': None, 'culture': 'British', 'name': 'William Leighton Leitch'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Ann Bateman'},
#  {'birthplace': None, 'culture': 'British', 'name': 'John Joshua Kirby'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Solomon Cole'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Elkington & Co.'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Rock & Co.'},
#  {'birthplace': None, 'culture': 'British?', 'name': 'J. Eames'},
#  {'birthplace': 'London',
#   'culture': 'British',
#   'name': 'George Seddon, Sons, & Shackleton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Robert Bright Marston'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Window & Bridge'},
#  {'birthplace': None, 'culture': 'British', 'name': 'A & E Seeley'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Anne Susan Zileri'},
#  {'birthplace': 'London, England',
#   'culture': 'British',
#   'name': 'Willoughby Wallace Hooper'},
#  {'birthplace': 'Scarborough England',
#   'culture': 'British',
#   'name': 'Frederic Leighton'},
#  {'birthplace': 'Plymouth, England',
#   'culture': 'British',
#   'name': 'William Payne'},
#  {'birthplace': 'York, England',
#   'culture': 'British',
#   'name': 'Albert Joseph Moore'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Patrick Caulfield'},
#  {'birthplace': None, 'culture': 'British', 'name': 'L. Caldesi'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Fradelle & Marshall'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Cornelius Bland'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Chapman & Co.'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Samuel Welder'},
#  {'birthplace': 'Dudley, England',
#   'culture': 'British',
#   'name': 'Thomas Phillips'},
#  {'birthplace': None, 'culture': 'British', 'name': 'J. Paton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'W. P. Barrett'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Richard Dalton'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Butterworth and Heath'},
#  {'birthplace': None, 'culture': 'British', 'name': 'Edward Francis Finden'},
#  ...]
